# %% [markdown]
# # Notebook Introduction
# This notebook is meant to follow up on the previous exploratory notebook done by shaul on some of our basic hypthesis regarding the quality of labels and labelers.<br>
# So far, we have found that:<br>
# - There is a significant difference between random and non-random dataset labels, albiet a lot of noise
# - Duration of task does not correlate neither with labels nor with random/non-random separation nor even length of sentences
# - high label varience (high disagreement) could be explainedby lazy labeling by one of the labelers
#
# in this notebook I'll try to answer on more questions:<br>
# - 1. How can we identify suspicous labelers?<br>
#     - higher mean for random pairs than for non-random
#     - very low label varience
# - 2. How does removing suspiocous labelers affect:<br>
#     - correlation between time and length
#     - amount (and randomness) of high disagreement pairs<br>
# - 3. can we identify a distinction between radicals and centralist?<br>
#     - centralist: lower mean for nonrandom pairs and higher mean for random pairs AND lower label standart deviation<br>
#     - extremist: high mean for non-random, low mean for random, and high standart deviation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob

# %%
# this block is for data preparation, for further reference check previous notebooks by Shaul & myself

for i, file in enumerate(glob.glob('data/*.csv')):
    if i==0:
        df = pd.read_csv(file, index_col = 0)
        df['dataset'] = file[5:-4].lower()
    else:
        temp = pd.read_csv(file, index_col = 0)
        temp['dataset'] = file[5:-4].lower()
        df = pd.concat((df,temp),axis = 0)
df['random'] = df.dataset.apply(lambda x: 'random' in  x).astype(int)
df['duration'] = pd.to_datetime(df.SubmitTime)-pd.to_datetime(df.AcceptTime)

df = df.drop(['HITId','HITTypeId', 'Title', 'Description', 'Keywords',
       'RequesterAnnotation', 'AssignmentDurationInSeconds', 'AssignmentId','AssignmentStatus','AcceptTime', 'SubmitTime','AutoApprovalTime', 'ApprovalTime', 'RejectionTime','RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate','Last30DaysApprovalRate', 'Last7DaysApprovalRate','Approve', 'Reject'],axis = 1)

df.columns = ['annotator', 'text1','text2','label','dataset','random','duration']

df.label = df.label.apply(lambda x:x[0]).astype(int)

df = df.reset_index()
df.drop(columns="index",inplace=True)
df['total_seconds'] = [int(df['duration'][i].total_seconds()) for i in range(df.shape[0])]

#As there is no id for same pair documents - I will create it
df["pair_id"] = [f"pair_{i//3}" for i in range(df.shape[0])]

#We will first replace 1-2 with [-1] and 4-5 with [1]
df['reduced_label'] = [1 if x > 3 else -1 if x < 3 else 0 for x in df.label]

# %%
df.head()
# Out:
#         annotator                                              text1  \
# 0  A3BCGN11HDM8QR  And he sent Eliakim , who was over the househo...
# 1  A3SQ00HYQN7FYB  And he sent Eliakim , who was over the househo...
# 2    A5WAWW70PYRP  And he sent Eliakim , who was over the househo...
# 3   AE608VRXK6M2E  And Ibneiah , the son of Jeroham , and Elah , ...
# 4  A22A52DRIIEV6K  And Ibneiah , the son of Jeroham , and Elah , ...
#
#                                                text2  label      dataset  \
# 0  And he sent Eliakim , who was over the house ,...      2  bible_human
# 1  And he sent Eliakim , who was over the house ,...      3  bible_human
# 2  And he sent Eliakim , who was over the house ,...      4  bible_human
# 3  and Ibneiah son of Jeroham , and Elah son of U...      5  bible_human
# 4  and Ibneiah son of Jeroham , and Elah son of U...      4  bible_human
#
#    random duration  total_seconds pair_id  reduced_label
# 0       0 00:00:12             12  pair_0             -1
# 1       0 00:00:12             12  pair_0              0
# 2       0 00:07:19            439  pair_0              1
# 3       0 00:10:12            612  pair_1              1
# 4       0 00:00:19             19  pair_1              1

# %% [markdown]
# Now that we have our basic dataset processed we are set to go do some EDA
# # Suspicious labelers
# 1. higher random than non random
# 2. very low varience
# 3. minimum value for random pairs equlas or larger than minimum values for non random pairs
#
# first thing we will want to do is get rid of all labels labeled by annotators that don't have at least 2 random and 2 non random labels, then we'll want to explore on how many labelers we are talking about

# %%
#df = df[df.annotator.apply(lambda x:x in set(labelers.index))]
labelers = df[df.random==0].groupby(['annotator'])['label'].agg(['size','mean','std','min','max'])
labelers = labelers[labelers['size']>1]
df = df[df.annotator.apply(lambda x:x in set(labelers.index))]



labelers_rand = df[df.random==1].groupby(['annotator'])['label'].agg(['size','mean','std','min','max'])
labelers_rand = labelers_rand[labelers_rand['size']>1]
labelers = labelers.join(labelers_rand, rsuffix = '_rand')
labelers['mean_random_gap'] = labelers['mean']-labelers['mean_rand']
labelers['std_ratio'] = labelers['std']/labelers['std_rand']

# %%
sns.distplot(labelers['mean_random_gap'])
labelers['mean_random_gap'].describe(percentiles=[ .1,.25,.5,.75,.9] )
# Out:
# count    252.000000
# mean       1.835311
# std        1.178063
# min       -0.928571
# 10%        0.000000
# 25%        1.023077
# 50%        2.004498
# 75%        2.746153
# 90%        3.299243
# max        3.840000
# Name: mean_random_gap, dtype: float64

# %% [markdown]
# 10 % of the labelers (23) have higher random pairs labels than non random

# %%
total_std = df.groupby('annotator')['label'].std()
total_std.name = 'total_std'
labelers = labelers.join(total_std).dropna()

# %%
labelers
# Out:
#                 size      mean       std  min  max  size_rand  mean_rand  \
# annotator
# A110SC5K5Y3IHS     2  1.500000  0.707107    1    2        3.0   1.333333
# A11YCM5MVQ35YY     8  3.000000  1.309307    1    5       25.0   1.200000
# A123PBQDU71I5O     4  2.750000  0.957427    2    4        3.0   3.333333
# A12BPQY35PARUO    93  3.537634  1.456314    1    5      114.0   1.035088
# A12NTFM8C8ZFSH    66  3.439394  1.479384    1    5        8.0   1.250000
# ...              ...       ...       ...  ...  ...        ...        ...
# AWLT05JTLRE5C     17  3.529412  1.124591    2    5        3.0   2.333333
# AX3EXSGDXF9ZJ     25  4.840000  0.374166    4    5        4.0   1.000000
# AX3RDV6XXR1XB     96  3.645833  1.247981    1    5      105.0   1.000000
# AYYSG3O9FNU15      6  4.333333  0.816497    3    5       10.0   1.200000
# AZYMR3317SUFN     54  4.074074  1.343775    1    5       39.0   1.358974
#
#                 std_rand  min_rand  max_rand  mean_random_gap  std_ratio  \
# annotator
# A110SC5K5Y3IHS  0.577350       1.0       2.0         0.166667   1.224745
# A11YCM5MVQ35YY  0.645497       1.0       4.0         1.800000   2.028370
# A123PBQDU71I5O  0.577350       3.0       4.0        -0.583333   1.658312
# A12BPQY35PARUO  0.227718       1.0       3.0         2.502547   6.395264
# A12NTFM8C8ZFSH  0.462910       1.0       2.0         2.189394   3.195835
# ...                  ...       ...       ...              ...        ...
# AWLT05JTLRE5C   1.527525       1.0       4.0         1.196078   0.736218
# AX3EXSGDXF9ZJ   0.000000       1.0       1.0         3.840000        inf
# AX3RDV6XXR1XB   0.000000       1.0       1.0         2.645833        inf
# AYYSG3O9FNU15   0.632456       1.0       3.0         3.133333   1.290994
# AZYMR3317SUFN   0.842527       1.0       4.0         2.715100   1.594934
#
#                 total_std
# annotator
# A110SC5K5Y3IHS   0.547723
# A11YCM5MVQ35YY   1.140674
# A123PBQDU71I5O   0.816497
# A12BPQY35PARUO   1.591450
# A12NTFM8C8ZFSH   1.561346
# ...                   ...
# AWLT05JTLRE5C    1.225819
# AX3EXSGDXF9ZJ    1.391388
# AX3RDV6XXR1XB    1.579596
# AYYSG3O9FNU15    1.707825
# AZYMR3317SUFN    1.774251
#
# [248 rows x 13 columns]

# %%
sns.distplot(labelers['total_std'])
print('number of labelers with 0 varience: {}, ({}%)'.format(
    len(labelers[labelers.total_std==0]),
    np.round(
        100*len(labelers[labelers.total_std==0])/len(labelers))
        ))
labelers.total_std.sort_values().describe(percentiles=[.05,.1,.25,.5,.75,.9])
# Out:
# number of labelers with 0 varience: 0, (0.0%)
# count    248.000000
# mean       1.349573
# std        0.387021
# min        0.258199
# 5%         0.593264
# 10%        0.806974
# 25%        1.073970
# 50%        1.431778
# 75%        1.662378
# 90%        1.780401
# max        2.190890
# Name: total_std, dtype: float64

# %%
very_suspicious = labelers[(labelers.total_std<1) & (labelers.mean_random_gap <0)]

# %%
very_suspicious
# Out:
#                 size      mean       std  min  max  size_rand  mean_rand  \
# annotator
# A123PBQDU71I5O     4  2.750000  0.957427    2    4        3.0   3.333333
# A14KIIR8FGYCHO   202  4.727723  0.683948    1    5      203.0   4.812808
# A1SBFOZG5J97Z1     7  1.571429  0.786796    1    3        2.0   2.500000
# A1U9XC376J6ZQ2   161  3.484472  0.829952    1    5      166.0   3.542169
# A21IZYCFI4AUYU   174  3.000000  0.680020    1    5      174.0   3.011494
# A2BA1R9MAHHWJH   195  2.728205  0.954087    1    5      199.0   2.964824
# A2UEGJLWV8VYZA    14  2.642857  1.081818    1    5       52.0   2.730769
# A32DRYN7M7HIZT    47  3.425532  0.683491    2    5        2.0   3.500000
# A3746TDKYH8SJ9   265  3.256604  1.008582    1    5      312.0   3.282051
# A3BCGN11HDM8QR   593  2.723440  0.710258    1    5      541.0   2.748614
# A3DQUOVL81OWGH    49  2.489796  0.710705    1    4       21.0   2.523810
# A3MZ64PK251KIC   100  3.240000  0.842315    1    5       30.0   3.366667
# A3VV0C7HCZP6HS    13  1.923077  0.277350    1    2        2.0   2.000000
# ACKF1WBCKVLY3    243  3.613169  0.930737    2    5      130.0   3.800000
# AJ32V2I6J9PET      3  1.666667  0.577350    1    2        2.0   2.000000
# ANVDIM96A57GD    131  4.183206  0.592278    3    5       46.0   4.391304
# AR9D5722RS6OC     38  3.578947  0.500355    3    4       23.0   3.739130
# ATDX69AZL4Y49     84  3.488095  0.649264    2    5       95.0   3.505263
# AWJ0LF6A0LXJN    312  3.304487  0.852599    2    5      366.0   3.426230
#
#                 std_rand  min_rand  max_rand  mean_random_gap  std_ratio  \
# annotator
# A123PBQDU71I5O  0.577350       3.0       4.0        -0.583333   1.658312
# A14KIIR8FGYCHO  0.471393       2.0       5.0        -0.085085   1.450908
# A1SBFOZG5J97Z1  0.707107       2.0       3.0        -0.928571   1.112697
# A1U9XC376J6ZQ2  0.775398       2.0       5.0        -0.057697   1.070356
# A21IZYCFI4AUYU  0.578902       2.0       4.0        -0.011494   1.174673
# A2BA1R9MAHHWJH  0.727365       2.0       4.0        -0.236619   1.311704
# A2UEGJLWV8VYZA  0.597885       1.0       4.0        -0.087912   1.809409
# A32DRYN7M7HIZT  0.707107       3.0       4.0        -0.074468   0.966602
# A3746TDKYH8SJ9  0.947461       1.0       5.0        -0.025448   1.064510
# A3BCGN11HDM8QR  0.655195       1.0       5.0        -0.025174   1.084041
# A3DQUOVL81OWGH  0.601585       2.0       4.0        -0.034014   1.181388
# A3MZ64PK251KIC  0.808717       2.0       5.0        -0.126667   1.041545
# A3VV0C7HCZP6HS  0.000000       2.0       2.0        -0.076923        inf
# ACKF1WBCKVLY3   0.562387       3.0       5.0        -0.186831   1.654977
# AJ32V2I6J9PET   0.000000       2.0       2.0        -0.333333        inf
# ANVDIM96A57GD   0.613850       3.0       5.0        -0.208098   0.964857
# AR9D5722RS6OC   0.540824       3.0       5.0        -0.160183   0.925173
# ATDX69AZL4Y49   0.633694       1.0       5.0        -0.017168   1.024570
# AWJ0LF6A0LXJN   0.887521       2.0       5.0        -0.121742   0.960652
#
#                 total_std
# annotator
# A123PBQDU71I5O   0.816497
# A14KIIR8FGYCHO   0.587924
# A1SBFOZG5J97Z1   0.833333
# A1U9XC376J6ZQ2   0.802007
# A21IZYCFI4AUYU   0.630604
# A2BA1R9MAHHWJH   0.854360
# A2UEGJLWV8VYZA   0.718228
# A32DRYN7M7HIZT   0.677003
# A3746TDKYH8SJ9   0.975234
# A3BCGN11HDM8QR   0.684357
# A3DQUOVL81OWGH   0.675664
# A3MZ64PK251KIC   0.833304
# A3VV0C7HCZP6HS   0.258199
# ACKF1WBCKVLY3    0.825328
# AJ32V2I6J9PET    0.447214
# ANVDIM96A57GD    0.603182
# AR9D5722RS6OC    0.517455
# ATDX69AZL4Y49    0.639297
# AWJ0LF6A0LXJN    0.873099

# %%
labelers[(labelers.total_std>=1) & (labelers.mean_random_gap <0)]
# Out:
#                 size      mean       std  min  max  size_rand  mean_rand  \
# annotator
# A168NGIUW93RV5   210  3.071429  1.275324    1    5      133.0   3.172932
# A1WZJ8VFE5TUO6    34  3.441176  1.956979    1    5       13.0   3.692308
# A3760PCQD2MPIO    20  1.300000  0.923381    1    4        8.0   1.875000
# AGGJUBFTYXCCZ    117  3.555556  1.054093    1    5      180.0   3.722222
#
#                 std_rand  min_rand  max_rand  mean_random_gap  std_ratio  \
# annotator
# A168NGIUW93RV5  1.299833       1.0       5.0        -0.101504   0.981145
# A1WZJ8VFE5TUO6  1.887883       1.0       5.0        -0.251131   1.036600
# A3760PCQD2MPIO  1.246423       1.0       4.0        -0.575000   0.740824
# AGGJUBFTYXCCZ   1.025134       1.0       5.0        -0.166667   1.028248
#
#                 total_std
# annotator
# A168NGIUW93RV5   1.283943
# A1WZJ8VFE5TUO6   1.920964
# A3760PCQD2MPIO   1.035737
# AGGJUBFTYXCCZ    1.038075

# %%
lowstd = labelers[(labelers['total_std']<1)]
neg_gap = labelers[labelers.mean_random_gap<0]
low_gap_std = labelers[(labelers.mean_random_gap<1) & (labelers.total_std<1)]

print(f'there are {len(lowstd)} labelers with standart deviation labels lower than 1, that constitute {np.round(len(lowstd)/len(labelers)*100,2)}% of the dataset.\n19 of those labelers also have a negetive mean difference between non-random and random pairs ({np.round(100*len(very_suspicious)/len(neg_gap),2)}% of negative gap).\n{len(low_gap_std)} labelers have std and gap lower than 1 ({np.round(100*len(low_gap_std)/len(lowstd),2)}%)') 

f,ax = plt.subplots(figsize = (8,8));
sns.regplot('total_std','mean_random_gap',data=labelers);
sns.regplot('total_std','mean_random_gap',data=low_gap_std,color= 'black', ci = None, fit_reg = False);

plt.plot(np.linspace(labelers.total_std.min(),labelers.total_std.max(),50),[0]*50,linestyle = '--', c = 'red')
plt.plot(np.linspace(labelers.total_std.min(),labelers.total_std.max(),50),[1]*50,linestyle = '--', c = 'purple')
plt.xlabel('standart deviation');
plt.ylabel('mean difference between non random and random sentences');
plt.title(label = 'STD VS. random pairs gap');
# Out:
# there are 50 labelers with standart deviation labels lower than 1, that constitute 20.16% of the dataset.
# 19 of those labelers also have a negetive mean difference between non-random and random pairs (82.61% of negative gap).
# 41 labelers have std and gap lower than 1 (82.0%)

# %%
# explore difference between minimum values for random and non-random
labelers['min_diff'] = labelers['min']-labelers['min_rand']
sns.distplot(labelers.min_diff, norm_hist=True)
labelers.min_diff.describe([.1,.25,.5,.75,.9])
# Out:
# count    248.000000
# mean       0.423387
# std        0.995017
# min       -1.000000
# 10%        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# 90%        2.000000
# max        4.000000
# Name: min_diff, dtype: float64

# %%
labelers[(labelers.min_diff<0) & (labelers.mean_random_gap>0)]
# Out:
#                 size      mean       std  min  max  size_rand  mean_rand  \
# annotator
# A2DVT1QU9ZKVQB    32  3.656250  1.405275    1    5        4.0   2.250000
# AB77P0ABU54TS     23  4.000000  1.044466    1    5        9.0   3.222222
# AE7UECBR4D5E6    211  3.492891  0.972820    1    5      150.0   3.460000
#
#                 std_rand  min_rand  max_rand  mean_random_gap  std_ratio  \
# annotator
# A2DVT1QU9ZKVQB  0.500000       2.0       3.0         1.406250   2.810550
# AB77P0ABU54TS   0.666667       2.0       4.0         0.777778   1.566699
# AE7UECBR4D5E6   0.902123       2.0       5.0         0.032891   1.078367
#
#                 total_std  min_diff
# annotator
# A2DVT1QU9ZKVQB   1.404076      -1.0
# AB77P0ABU54TS    1.007532      -1.0
# AE7UECBR4D5E6    0.942948      -1.0

# %%
df[df.annotator=='A2DVT1QU9ZKVQB']
# Out:
#             annotator                                              text1  \
# 2440   A2DVT1QU9ZKVQB  Yahweh called yet again , `` Samuel ! '' Samue...
# 6136   A2DVT1QU9ZKVQB       i doubt he would have so many television s .
# 6846   A2DVT1QU9ZKVQB  recently has a pair of companions unable to ha...
# 6869   A2DVT1QU9ZKVQB  i will be your significant other is you come t...
# 7020   A2DVT1QU9ZKVQB  you are not considered un less you , " pay it ...
# 7094   A2DVT1QU9ZKVQB                             did you go on a date ?
# 7493   A2DVT1QU9ZKVQB  because some women send men  tiny messages wit...
# 7852   A2DVT1QU9ZKVQB             when she slow s down the love making .
# 7882   A2DVT1QU9ZKVQB  if you do , then i would say that it is real a...
# 8174   A2DVT1QU9ZKVQB  a trip to an amusement park in cluding roller ...
# 8258   A2DVT1QU9ZKVQB  no , there is no way that girls will ever unde...
# 8385   A2DVT1QU9ZKVQB  if you want to live , talk , and dream about i...
# 8709   A2DVT1QU9ZKVQB  fall ing in love , real love , is magical . . ...
# 29246  A2DVT1QU9ZKVQB                                     was seeking to
# 29261  A2DVT1QU9ZKVQB                                       policy goals
# 29341  A2DVT1QU9ZKVQB                          of the commission for the
# 29397  A2DVT1QU9ZKVQB                               it is concerned that
# 29481  A2DVT1QU9ZKVQB                                           men were
# 29527  A2DVT1QU9ZKVQB                                      of ammunition
# 29657  A2DVT1QU9ZKVQB                             on the question of the
# 30222  A2DVT1QU9ZKVQB                                   , the council is
# 30536  A2DVT1QU9ZKVQB                               first and foremost ,
# 30799  A2DVT1QU9ZKVQB                   the security council is ready to
# 31092  A2DVT1QU9ZKVQB                                         must be of
# 31708  A2DVT1QU9ZKVQB                        the assembly also wishes to
# 31899  A2DVT1QU9ZKVQB                                  outcomes of these
# 32012  A2DVT1QU9ZKVQB                                     you doing okay
# 33878  A2DVT1QU9ZKVQB  steve was professional and found exactly the r...
# 33883  A2DVT1QU9ZKVQB  when she did n't answer him quickly enough , h...
# 33951  A2DVT1QU9ZKVQB        pricing is both affordable and reasonable .
# 34365  A2DVT1QU9ZKVQB                   this is pretty darn good pizza !
# 34560  A2DVT1QU9ZKVQB             their lunch special is a great value !
# 37335  A2DVT1QU9ZKVQB  i ordered garlic bread and fettuccine alfredo ...
# 37666  A2DVT1QU9ZKVQB       the atmosphere is at the sugar bowl is fun .
# 38506  A2DVT1QU9ZKVQB  it looks like blended up chicken put into the ...
# 38857  A2DVT1QU9ZKVQB  i just had probably one of the best restaurant...
#
#                                                    text2  label  \
# 2440   And Jehovah called again , Samuel ! And Samuel...      5
# 6136        i doubt he would have so many television s .      5
# 6846   i have two friends who could not play battle f...      5
# 6869          come to my town , and i ' ll be with you .      5
# 7020   you will not be considered un less you do it b...      4
# 7094   without lust as in you only go on dates , corr...      4
# 7493   because some women send subtle messages to men...      5
# 7852                 has she halte d sleeping with you ?      3
# 7882   if you truly do , i would say that is was a re...      5
# 8174   a trip to a amusement park such as a roller co...      4
# 8258    there is no way that women will understand men .      5
# 8385   if you want to live and talk and dream about i...      5
# 8709   truly fall ing in love is magical until realit...      5
# 29246                                     will strive to      2
# 29261                                    political goals      4
# 29341                                      committees on      2
# 29397                         it notes with concern that      4
# 29481                                       two men were      4
# 29527                                        munitions ,      3
# 29657                                    on the issue of      4
# 30222                             , the council extended      4
# 30536                              the first is that the      4
# 30799                            the council is ready to      4
# 31092                                   must be given to      2
# 31708                         the assembly too wishes to      5
# 31899                                 results from these      5
# 32012                                you 're gonna be ok      4
# 33878  steve was totally unprofessional and did n't f...      2
# 33883  when she did n't answer him quickly enough , h...      1
# 33951                          the pricing is a bit much      1
# 34365                    this is a pretty darn bad pizza      1
# 34560              their lunch special is a poor value .      1
# 37335  there is n't a great selection of salads or pa...      2
# 37666  when i picked up the order , i was given anoth...      3
# 38506         the equipment is very new and looks good .      2
# 38857   the kebab dishes and service was n't that good .      2
#
#                   dataset  random duration  total_seconds     pair_id  \
# 2440          bible_human       0 00:00:08              8    pair_813
# 6136   gyafc_formal_human       0 00:00:07              7   pair_2045
# 6846   gyafc_formal_human       0 00:00:11             11   pair_2282
# 6869   gyafc_formal_human       0 00:00:10             10   pair_2289
# 7020   gyafc_formal_human       0 00:00:08              8   pair_2340
# 7094   gyafc_formal_human       0 00:00:12             12   pair_2364
# 7493   gyafc_formal_human       0 00:01:19             79   pair_2497
# 7852   gyafc_formal_human       0 00:00:23             23   pair_2617
# 7882   gyafc_formal_human       0 00:00:10             10   pair_2627
# 8174   gyafc_formal_human       0 00:00:15             15   pair_2724
# 8258   gyafc_formal_human       0 00:00:23             23   pair_2752
# 8385   gyafc_formal_human       0 00:00:28             28   pair_2795
# 8709   gyafc_formal_human       0 00:00:11             11   pair_2903
# 29246    paraphrase_human       0 00:00:12             12   pair_9748
# 29261    paraphrase_human       0 00:02:29            149   pair_9753
# 29341    paraphrase_human       0 00:00:07              7   pair_9780
# 29397    paraphrase_human       0 00:00:07              7   pair_9799
# 29481    paraphrase_human       0 00:00:07              7   pair_9827
# 29527    paraphrase_human       0 00:00:06              6   pair_9842
# 29657    paraphrase_human       0 00:00:08              8   pair_9885
# 30222    paraphrase_human       0 00:00:05              5  pair_10074
# 30536    paraphrase_human       0 00:00:07              7  pair_10178
# 30799    paraphrase_human       0 00:00:06              6  pair_10266
# 31092    paraphrase_human       0 00:00:07              7  pair_10364
# 31708    paraphrase_human       0 00:00:05              5  pair_10569
# 31899    paraphrase_human       0 00:00:07              7  pair_10633
# 32012    paraphrase_human       0 00:00:06              6  pair_10670
# 33878          yelp_human       0 00:00:08              8  pair_11292
# 33883          yelp_human       0 00:00:11             11  pair_11294
# 33951          yelp_human       0 00:00:08              8  pair_11317
# 34365          yelp_human       0 00:00:21             21  pair_11455
# 34560          yelp_human       0 00:10:25            625  pair_11520
# 37335   yelp_random_human       1 00:00:09              9  pair_12445
# 37666   yelp_random_human       1 00:00:12             12  pair_12555
# 38506   yelp_random_human       1 00:00:08              8  pair_12835
# 38857   yelp_random_human       1 00:00:17             17  pair_12952
#
#        reduced_label
# 2440               1
# 6136               1
# 6846               1
# 6869               1
# 7020               1
# 7094               1
# 7493               1
# 7852               0
# 7882               1
# 8174               1
# 8258               1
# 8385               1
# 8709               1
# 29246             -1
# 29261              1
# 29341             -1
# 29397              1
# 29481              1
# 29527              0
# 29657              1
# 30222              1
# 30536              1
# 30799              1
# 31092             -1
# 31708              1
# 31899              1
# 32012              1
# 33878             -1
# 33883             -1
# 33951             -1
# 34365             -1
# 34560             -1
# 37335             -1
# 37666              0
# 38506             -1
# 38857             -1

# %% [markdown]
# it seems that adding the difference between minimum random and non-random doesn' add much nformation.<br>
# the only new suspicious labeler added, looks like a legit one (albeit a bit harsh negation effect on similarity)

# %%
legit = labelers[(labelers.mean_random_gap>0) & (labelers.total_std>1)]
legit_df = df[df.annotator.apply(lambda x: x in legit.index)]

# %%
len(legit_df)/len(df), len(legit)/df.annotator.nunique(), len(legit)/len(labelers)
# Out:
# (0.5259261156940104, 0.5172413793103449, 0.7258064516129032)

# %%
sns.distplot(legit['mean_random_gap']);
plt.title('mean gap between non-random and random pairs distribution after filtering');

# %% [markdown]
# # Conclusions:
# - it appears that mean gap between non-random and random sentencs pair is a good indicator for bad labelers
# - low standard deviation also is a fair indicator for lazy labaling
# - after removing labelers which doesn't have both random and nn random sentences, lower std than 1 and lower mean gap than 0, we have:<br>
#     - 194 unique labelers (55.7 % of original dataset and 78.2% of dataset after filtering labeler that don't have both random and non-random labels)
#     - 23910 labeled pairs (61.2 % of original data)
# - if we use a stricter criterion (std>1 & mean gap>1):
#     - 180 labelers (51.% of labelers, 72.5% after initial filtering)
#     - 20529 labeled pairs (52.6% of data)
#
# # Next step:
# Re-running some of Shaul's analysis on the filtered dataset
