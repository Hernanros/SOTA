# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import zipfile
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
import wordfreq

import src
import src.chrF, src.WMD

# %%
df = pd.read_csv("data/combined/filtered_combined.csv", index_col = 0)
df.reset_index(inplace=True)
df.drop(columns="index",inplace=True)

# %%
# from gensim.test.utils import datapath, get_tmpfile
# from gensim.models import KeyedVectors
# from gensim.scripts.glove2word2vec import glove2word2vec

# glove_file = datapath('C:/SOTA/glove/glove.6B.300d.txt')
# tmp_file = get_tmpfile('W2V.txt')

# _ = glove2word2vec(glove_file, tmp_file)

# model = KeyedVectors.load_word2vec_format(tmp_file)

# %%
with open('data/other/ba_all.txt') as f:
    myNames = f.read()
    myNames=myNames.split('\n')

# %%
df.head()
# Out:
#         annotator                                              text1  \
# 0  A3SQ00HYQN7FYB  And he sent Eliakim , who was over the househo...
# 1  A168NGIUW93RV5  The word of the Lord which came to Joel , the ...
# 2  A2Z5WHZ0A2JJ6A                              Adam , Seth , Enosh ,
# 3  A351BKQC7NEH3A                              Adam , Seth , Enosh ,
# 4   AE7UECBR4D5E6  having become by so much better than the angel...
#
#                                                text2  label      dataset  \
# 0  And he sent Eliakim , who was over the house ,...      3  bible_human
# 1  The word of the Lord that came to Joel the son...      4  bible_human
# 2                              Adam , Seth , Enosh ,      5  bible_human
# 3                              Adam , Seth , Enosh ,      5  bible_human
# 4  taking a place by so much better than the ange...      3  bible_human
#
#    random                   duration  total_seconds pair_id  reduced_label  \
# ...

# %%
annot_std_semantic = df[(df['bleu_score_1'] > 0.8) & (df['dif_sent'] > 1.9)].groupby('annotator')['label'].std().dropna()
ba_semantics = list(annot_std_semantic[annot_std_semantic > 1.0].index)

# %%
skinny_df = df[df.annotator.apply(lambda x: x not in ba_semantics)]

df_unqiue_pairs = skinny_df.groupby('pair_id').first()

# %%
blu_scores = blu.run(skinny_df)
cosine_scores = cosine.run(df_new_scores)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-9e24fee4982e> in <module>
#       1 df_new_scores = blu.run(skinny_df)
# ----> 2 df_new_scores = cosine.run(df_new_scores)
#
# ~/workspace/GitHub/SOTA/src/cosine_similarites.py in run(self, df)
#      62                                                                                  stopwords_remove=False,
#      63                                                                                  remove_non_model=False,
# ---> 64                                                                                  method='glove'), axis=1)
#      65         df['glove_withoutstop'] = df.apply(lambda x: self.embedding_cosine_distance(str(x.text1), str(x.text2),
#      66                                                                                     stopwords_remove=True,
#
# ...

# %%
df_new_scores = elmo_euclidean.run(df_new_scores)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-0a204370849a> in <module>
# ----> 1 df_new_scores = elmo_euclidean.run(df_new_scores)
#
# ~/workspace/GitHub/SOTA/src/elmo_euclidean_distance.py in run(self, df)
#      20         # apply function to all word pairs in dataset
#      21         df['L2_score'] = df.apply(lambda x: euclidean(self.create_embedding(x.text1), self.create_embedding(x.text2)),
# ---> 22                                   axis=1)
#      23         return df
#
# ~/workspace/GitHub/SOTA/venv_sota/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ...

# %%
df_new_scores['BertScore'] = bert.run(df_unqiue_pairs)

# %%
df_unqiue_pairs['BertScore'] = bert_scores[2].cpu().numpy()

# %%
blu = src.bleu.Bleu()
cosine = src.cosine_similarites.CosineSimilarity()
# Out:
# [nltk_data] Downloading package punkt to /home/shaul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/shaul/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /home/shaul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/shaul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/shaul/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# INFO:torchtext.vocab:Downloading vectors from http://nlp.stanford.edu/data/glove.twitter.27B.zip
# .vector_cache/glove.twitter.27B.zip: 1.52GB [12:39, 2.00MB/s]
# INFO:torchtext.vocab:Extracting vectors into .vector_cache
# ...

# %%
elmo_euclidean = src.elmo_euclidean_distance.EuclideanElmoDistance()
bert = src.bertscore.BertScore()
chrf = src.chrF.chrFScore() ##
pos = src.POS_distance.POSDistance()  ##
# wmd = src.WMD() ##
ngram_overlap = src.ngram_overlap.NgramOverlap(3) ##
rouge = src.ROUGE.rouge()
# Out:
# INFO:allennlp.commands.elmo:Initializing ELMo.
# [nltk_data] Downloading package punkt to /home/shaul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/shaul/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# INFO:torchtext.vocab:Loading vectors from .vector_cache/glove.twitter.27B.100d.txt.pt
# Test: 100% ||                                      | Time:  0:19:00   1.8 MiB/s
# INFO:gensim.models.utils_any2vec:loading projection weights from data/pretrained_vectors/glove.840B.300d.zip
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-0d954f6f30b6> in <module>
#       3 chrf = src.chrF.chrFScore()
#       4 pos = src.POS_distance.POSDistance()
# ----> 5 wmd = src.WMD()
# ...

# %%
ngram_overlap = src.ngram_overlap.NgramOverlap(3)
rouge = src.ROUGE()
